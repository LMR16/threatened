# %%
import pandas as pd
from pathlib import Path

path = Path("archive/especies.csv")

def read_csv(path):
    csv = pd.read_csv(path, sep=';', encoding='latin-1')
    return csv

# %%
csv = read_csv(path)

df = pd.DataFrame(csv)

df
# Out:
#      Grupão         Grupo       Família      Espécie (Simplificado)  \
# 0     Flora  Angiospermas    Salicaceae            Abatia angeliana
# 1     Fauna          Aves      Cracidae           Aburria jacutinga
# 2     Flora  Angiospermas     Malvaceae          Abutilon anodoides
# 3     Flora  Angiospermas     Malvaceae          Abutilon nigricans
# 4     Flora  Angiospermas   Santalaceae  Acanthosyris paulo-alvinii
# ...     ...           ...           ...                         ...
# 3282  Flora  Angiospermas   Orchidaceae         Zygopetalum pabstii
# 3283  Flora  Angiospermas   Orchidaceae       Zygostates kuhlmannii
# 3284  Flora  Angiospermas   Orchidaceae    Zygostates linearisepala
# 3285  Flora  Angiospermas  Gentianaceae         Zygostigma australe
# 3286    NaN           NaN           NaN                         NaN
#
#      Nome Comum Categoria
# 0         Vazio        VU
# 1     Jacutinga        EN
# 2         Vazio        CR
# 3         Vazio        CR
# ...
